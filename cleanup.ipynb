# %%
import pandas as pd

# %%
comments = pd.read_csv("./bank-data/bank-comments.csv", sep="\t")
customers = pd.read_csv("./bank-data/bank-tabular.csv", sep="\t")

# %% [markdown]
# # Data Cleaning
#
# ## Issues with the comments:
#
# - [ ] NaN values in the comments column
# - [ ] special characters in the comments column like asterisks, umlaute, brackets, etc.
# - [ ] Spelling mistakes in the comments column
#
# ## Issues with the customers
#
# - [ ] non structured gender names
#   - [ ] Male / Female
#   - [ ] m/f
#   - [ ] Unspecified
#   - [ ] NaN
#   - [ ] Not Specified
#
# - [ ] NaN values
#   - [ ] age
#   - [ ] customers
#   - [ ] location
#   - [ ] convinience
#   - [ ] customer service
#   - [ ] online_banking
#   - [ ] fees_charges
#   - [ ] community_involvement

# %%
customers.head(50)
# Out:
#     customer_id        date customer_gender  customer_age customer_location  \
# 0        216604  2022-08-22            Male          50.0           Munster
# 1        259276  2022-11-23          Female          61.0          Leinster
# 2        265459  2022-01-21          Female          63.0           Munster
# 3         58770  2022-03-13               f           NaN          Leinster
# 4        318031  2022-08-08          Female          41.0          Leinster
# 5        241092  2021-01-30          Female          71.0               NaN
# 6        380865  2022-11-20     Unspecified          40.0           Munster
# 7        145660  2022-10-21          Female          46.0           Munster
# 8        219361  2021-09-25            Male          65.0          Leinster
# 9        304040  2021-02-02          Female          69.0          Connacht
# 10       314559  2021-01-06            Male          56.0           Munster
# ...
